# %% [markdown]
# # Extraction Using OpenAI functions

# %% [markdown]
# In this notebook I process and structure a whatsapp conversation from the Morningside Community whatsapp group from 22 November 2023.

# %%
# !python --version

# %%
# !pip show openai

# %%
# Set up the environment and load the required modules
import os
import openai
import re
import json

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain.utils.openai_functions import convert_pydantic_to_openai_function
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser, JsonKeyOutputFunctionsParser

# %% [markdown]
# ## Extraction
#
# Extraction is similar to tagging, but used for extracting multiple pieces of information.
# In this notebook, extraction can be considered as a preprocessing step as we don't interrogate the complete chat text, but rather a filtered version of it.

# %%
# Set up the Person and Information Classes. These inherit from the python Base Model
class Person(BaseModel):
    """Information about a person."""
    name: str = Field(description="person's name")
    message: str = Field(description="a brief summary of the person's message") 
    sentiment: str = Field(description="sentiment of message, should be `pos`, `neg`, or `neutral`")

# %%
class Information(BaseModel):
    """Information to extract."""
    people: List[Person] = Field(description="List of info about people")

# %%
# Convert pydantic to openai functions. 
# This is just to illustrate what happens under the hood
convert_pydantic_to_openai_function(Information)
# Out:
# {'name': 'Information',
#  'description': 'Information to extract.',
#  'parameters': {'title': 'Information',
#   'description': 'Information to extract.',
#   'type': 'object',
#   'properties': {'people': {'title': 'People',
#     'description': 'List of info about people',
#     'type': 'array',
#     'items': {'title': 'Person',
#      'description': 'Information about a person.',
#      'type': 'object',
#      'properties': {'name': {'title': 'Name',
#        'description': "person's name",
#        'type': 'string'},
#       'message': {'title': 'Message',
#        'description': "a brief summary of the person's message",
#        'type': 'string'},
#       'sentiment': {'title': 'Sentiment',
#        'description': 'sentiment of message, should be `pos`, `neg`, or `neutral`',
#        'type': 'string'}},
#      'required': ['name', 'message', 'sentiment']}}},
#   'required': ['people']}}

# %%
# Declare the language model
model = ChatOpenAI(temperature=0, model="gpt-4-1106-preview")

# %%
# Set up the extraction functions and the extraction model
extraction_functions = [convert_pydantic_to_openai_function(Information)]
extraction_model = model.bind(functions=extraction_functions, function_call={"name": "Information"})

# %%
# Define the prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "Extract the relevant information, if not explicitly provided do not guess. \
    You can extract partial info."),
    ("human", "{input}")
])

# %%
#Set up the extraction chain
extraction_chain = prompt | extraction_model | JsonKeyOutputFunctionsParser(key_name="people")

# %%
# Define the batch size for processing the chat
batch_size = 10  # Adjust batch size as needed

# %% [markdown]
# Proces the chat in batches

# %% [markdown]
# The script also checks each line to determine whether it's the start of a new message (using the regular expression pattern). If a line doesn't match the pattern, it's considered a continuation of the previous message. This way, the script can handle messages that span multiple lines, preventing them from being truncated or split incorrectly between batches.

# %%
def parse_line(line):
    pattern = r"\[(\d{4}/\d{2}/\d{2}), (\d{2}:\d{2}:\d{2})\] ([^:]+): (.*)"
    match = re.match(pattern, line)
    if match:
        return {
            "date": match.group(1),
            "time": match.group(2),
            "sender": match.group(3).strip(),
            "message": match.group(4).strip()
        }
    else:
        return None

def process_batch(batch):
    parsed_batch = [parse_line(line) for line in batch if line.strip()]
    return [line for line in parsed_batch if line]  # Remove None entries

aggregated_results = []

with open('community_chat.txt', 'r', encoding='utf-8') as file:
    batch = []
    previous_line = ""
    for line in file:
        if re.match(r"\[\d{4}/\d{2}/\d{2}, \d{2}:\d{2}:\d{2}\]", line):
            # Start of a new message
            if previous_line:  # If there's a previous line, add it to the batch
                batch.append(previous_line)
            previous_line = line
        else:
            # Continuation of a previous message
            previous_line += line

        if len(batch) >= batch_size:
            parsed_batch = process_batch(batch)
            result = extraction_chain.invoke({"input": parsed_batch})
            aggregated_results.extend(result)
            batch = []

    if previous_line:  # Add the last line if it exists
        batch.append(previous_line)

    if batch:  # Process the final batch
        parsed_batch = process_batch(batch)
        result = extraction_chain.invoke({"input": parsed_batch})
        aggregated_results.extend(result)

# Convert the aggregated_results to JSON 
json_string = json.dumps(aggregated_results, indent=4)

# Save the JSON string output to a file
with open('chat.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_string)

# %%
#Optional: In case of timeout, save whatever you've got so far
# Convert the aggregated_results to JSON 
json_string = json.dumps(aggregated_results, indent=4)

# Save the JSON string output to a file
with open('community_chat.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_string)

# %%
# Print the string in nice json
# First convert it to a Python object (list or dictionary)
community_json_data=json.loads(json_string)
community_json_data
# Out:
# [{'name': 'Jenny Wertheimer',
#   'message': 'created this group',
#   'sentiment': 'neutral'},
#  {'name': 'Scott', 'message': 'added you', 'sentiment': 'neutral'},
#  {'name': 'Scott', 'message': '👍', 'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Scott added Michelle & Giuseppe',
#   'sentiment': 'neutral'},
#  {'name': 'Giuseppe',
#   'message': 'Hi Scott please add Mish 0824565294',
#   'sentiment': 'neutral'},
#  {'name': 'John S',
#   'message': 'Ref the "noise disturbances" from the Park and surrounds, I will 100% support on behalf of Morningside Villas - it is not only the Park, but also "inconsiderate" neighboring properties as flagged the past while......',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': "Thanks All, I will let you know when I've set up the meeting if anyone else wants to attend..",
#   'sentiment': 'pos'},
#  {'name': 'John S',
#   'message': 'Thanks Scott - based on complaints as raised lately, it is not so much the Park as Private Properties that do not consider their neighbors....',
#   'sentiment': 'neg'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Hi Scott, I am in Ridgeway and you have my support !!',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'You have my support.',
#   'sentiment': 'pos'},
#  {'name': 'Elaine', 'message': 'Yes you have our support', 'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': "Loud music sounds like it's from Ratcliff. Anyone else can hear it?",
#   'sentiment': 'neutral'},
#  {'name': 'Dr Mark Wertheimer',
#   'message': 'Please note: Burglary limpopo avenue gallo manor yesterday at 12.30.broke gate off arms broke security and wooden front door. Please. take note: 3 or 4 guys may visit your home claiming they are from water company, to install shower caps, to save water. Or they will claim they are from Electricity company to change energy-saving electric bulbs for free as part of government lay down program. They have been spotted in so many areas. Please. do NOT let them in. They are Robbers, robbing people at gun-point. Please alert all your contacts, as you may save lives. Make sure doors are locked at all times and Please do not open door to strangers. Please forward immediately to save lives n property!!!',
#   'sentiment': 'neg'},
#  {'name': 'Debby van Zyl',
#   'message': 'Thank y u for this. Can someone please provide me with company contact details for a Borehole? I recall the conversation in earlier messages in this group.',
#   'sentiment': 'neutral'},
#  {'name': 'Annmarie',
#   'message': 'Found bunch of keys with 2 remotes in park. Look like could have been there awhile. Pls let me know if u think they may be yours',
#   'sentiment': 'neutral'},
#  {'name': 'Dr Mark Wertheimer',
#   'message': 'CHAPTER 3',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Very nice but that was explosives from the building site by the river not fireworks',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Hope all well Lester',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': 'If anyone has a spare domestic room they are interested in renting out for a Security Guard who works in the area. Inbox me',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Scott added Kim McCormick',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': "Thanks Scott. Does anyone know what's going with the tent on the lawn in the park?",
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "It's a city parks function this weekend, I'm waiting for city parks to come back to me on what it is and why the community hasn't been informed... I'm sure there will be big noise which isn't acceptable for our small community and urban area.. will let you know what they come back with..",
#   'sentiment': 'neg'},
#  {'name': 'Janet Byrne',
#   'message': 'I chatted to the guys erecting it on monday evening. They said it was for a wedding on the weekend. I further chatted to the caretaker who lives by the jungle gym and he also confirmed it was a wedding with over 500 guests expected. He said it was somebody from parliament. Goodness know how parking and sanitation is being organised.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Oh no. Not good news.',
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Earplugs buy earplugs.',
#   'sentiment': 'neg'},
#  {'name': 'Gosia',
#   'message': 'It\'s lovely that "good" activities are taking place at the Park... the more it\'s used for good purposes, the smaller the chances of bad activities/crime taking place...',
#   'sentiment': 'pos'},
#  {'name': 'Scott',
#   'message': 'An event such as a wedding of 250-500 people is not suitable for our area... the potential problems of that number of wedding guests, alcohol, lack of parking, lack of ablutions can only spell disaster...',
#   'sentiment': 'neg'},
#  {'name': 'Ross Smith',
#   'message': 'Walk dogs without scoops \n😩',
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick', 'message': 'Lol', 'sentiment': 'neutral'},
#  {'name': 'Angie Makwetla',
#   'message': 'I know the family concerned and they are decent law abiding citizens. The wedding is for 300 people and it will end at 19:30. Portable toilets have been organized.',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'When there is an event on in the park the music echoes over the house tops and it sounds like the part us being held inside my lounge and bedroom. There is nowhere in my home to escape the noise.',
#   'sentiment': 'neg'},
#  {'name': 'Angie Makwetla',
#   'message': "Thank for the positive response. I'm not sure where the notification should have come from. This is another lesson to be kept in mind for the future.",
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': "If you're going to the wedding angie... Post a pic from the inside \n😊😊 wishing the couple a splendid day.",
#   'sentiment': 'pos'},
#  {'name': 'Scott',
#   'message': "Thanks for letting us know Angie, I've got no issue with your friends who are getting married but rather with city parks who haven't followed the correct procedures..",
#   'sentiment': 'neutral'},
#  {'name': 'Nasreen Ameen',
#   'message': 'Justin added Nasreen Ameen',
#   'sentiment': 'neutral'},
#  {'name': 'Angie Makwetla',
#   'message': 'Unfortunately I am not attending. Out of town. Thank u for the blessings.',
#   'sentiment': 'neg'},
#  {'name': 'Giuseppe',
#   'message': 'There is a Labrador on the loose in Stewart road.',
#   'sentiment': 'neutral'},
#  {'name': 'Giuseppe',
#   'message': 'Does anybody know why a band is sound checking in the park at 10.45pm on a week night?',
#   'sentiment': 'neg'},
#  {'name': 'Janet Byrne',
#   'message': "There are 2 weddings in the park on Saturday. One in marquee and one in the hall. Marquee wedding to finish 7.30. Don't know about other one.",
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "Scott, I'm afraid you right. It's just not on. If the park keeps doing this let's start a petition. The music is not the worst it's the Base that makes the entire house feel like it's shaking. I am not a well person. My home is my rest place I do not enjoy lying in a sick bed and getting even more of a headache from the vibrations emitted by the park entertainment. Blessings or no blessings. We just spent a fortune on upgrading security because of the park needing public access. So now what? We have to spend more sound proofing our homes for weddings and Sunday morning services. Even then you can't go outside your own home you have to stay indoors because its so loud in your garden. Not on. Enough is enough. There is a noise control law.",
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "Had everyone else been enjoying the pulsating music all afternoon long. This is unjustifiable it's a suburban area not a commercial area. There are sick people and old people and babies and children that need their afternoon nap and teenagers studying.",
#   'sentiment': 'neg'},
#  {'name': 'Rudolph',
#   'message': 'Hi Mitch, I agree with you sadly though we will have to live through this one.',
#   'sentiment': 'neg'},
#  {'name': 'John S',
#   'message': 'I am only too happy to sign a petition with regards this issue (currently) - Lord help us tomorrow with DJ\'s and Diwali and the lack of Park to Resident "engagement"...... That said, I am 100% in support of Ernest Ullman being utilized RESPONSIBLY. Does the Park contribute to MMAP? If not, can we not request that JRA block off access due to "security concerns" and "antisocial behavior"..... It is about time that the Park became part of the "community", rather than a "concern".....',
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Scott has dealt extensively with the park board ... by the time we all realised what was taking place it was far too late to make them cancel. Even I have a heart and am not going to do blushing bride out of a wedding venue a few days before the event. I lay the blame for this squarely on the shoulders of the park who organised this without informing anyone or consulting any of us. If I had a party at home with music so loud that at least 30 houses could dance to in their living rooms and bedrooms I would be shut down by noise control. When I did have a party of that nature I notified everyone in a 3 street radius and apologised and invited them all to join us. No one complained and no one joined us. More is the pity. But if I can do it. The park surely had to. Justin.',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': 'Hi All, city parks gave this contact person who is responsible for the wedding in the park tomorrow, Ntavha Nemukula, 0827075600..',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'I have been fighting these events for 2 years now and need the community to add your voices to stop these loud disturbing events.',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': "I'm just against loud disturbing events, the revenue for the community center and city parks is very important but not to the detriment of the neighborhood, things have gone well with the recreation center in the last year with proper rules and regulations in place.",
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'I have contact details to enquire regarding where the funds go, at the moment SUPCA is maintaining the park and not city parks. So money is made from Ullman and very little goes back into the park and facilities...',
#   'sentiment': 'neg'},
#  {'name': 'Melanie',
#   'message': 'Thanks for the clarification Scott. Appreciated.',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'For me it\'s the fact that the music is too loud and not being informed that are the two major problems. That\'s what broke my " camel"back today.',
#   'sentiment': 'neg'},
#  {'name': '~\rMarcilin Moodley',
#   'message': 'Lord help us with Diwali?',
#   'sentiment': 'neutral'},
#  {'name': '~\rPelayo Omotoso',
#   'message': 'Hi Scott, please add Tembi 0722484467',
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': 'I think I just drove past the house where the bride is. Family and friends dancing. So exciting. And so beautiful. If her family is on this group - wishing you all the best for this wonderful day.',
#   'sentiment': 'pos'},
#  {'name': 'Angie Makwetla',
#   'message': "That's the spirit!! I will pass on your good wishes. Angie",
#   'sentiment': 'pos'},
#  {'name': 'Andre',
#   'message': 'Yes very beautiful indeed.',
#   'sentiment': 'pos'},
#  {'name': 'Andre',
#   'message': 'Hope the day for them is full of blessings and happiness.',
#   'sentiment': 'pos'},
#  {'name': 'Louis',
#   'message': 'Also drove past and saw many huge smiles! All the best to the lovely couple.',
#   'sentiment': 'pos'},
#  {'name': 'Bridget Radebe',
#   'message': "Hello MMAP community. Just wanted to let you know that my fiancÃ© Ekow and I are having our traditional wedding at our home of 2 Lynton a Road on the Friday evening of 25 November 2016 from 7pm but expect to wrap up by midnight. We are expecting a number of guests but are requesting them to uber rather than park on the street and also don't expect to be a rowdy affair. We have also personally invited our immediate neighbours.",
#   'sentiment': 'neutral'},
#  {'name': 'Melanie',
#   'message': 'Such wonderful news congratulations! Wishing you and Ekow many blessings on this wonderful journey!',
#   'sentiment': 'pos'},
#  {'name': 'Kim', 'message': 'Congratulations', 'sentiment': 'pos'},
#  {'name': 'Bridget Radebe',
#   'message': 'Thanks Mel and Kim',
#   'sentiment': 'pos'},
#  {'name': 'Elaine',
#   'message': "What part of no fireworks do these people not understand, I can't believe they are so inconsiderate to everyone around them and the animals.",
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': "It's Diwali this weekend, so it's probably not the wedding.",
#   'sentiment': 'neutral'},
#  {'name': 'Tembiwe', 'message': 'Scott added Tembiwe', 'sentiment': 'neutral'},
#  {'name': 'Jon',
#   'message': 'Please add 0835617890 to this group. Thanks.',
#   'sentiment': 'neutral'},
#  {'name': 'Clamber Club Babies, Toddlers, and Sports for Preschools',
#   'message': 'Scott added Clamber Club Babies, Toddlers, and Sports for Preschools',
#   'sentiment': 'neutral'},
#  {'name': 'Giuseppe',
#   'message': 'Congrats to Ekow and Bridget',
#   'sentiment': 'pos'},
#  {'name': 'States',
#   'message': 'Priya I Trust you have enjoyed your DIWALI.',
#   'sentiment': 'pos'},
#  {'name': 'States', 'message': 'CHAPTER 3', 'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'This was posted by mark. oct.,2',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Congrats Ekow and Bridget. May all your dreams come true.',
#   'sentiment': 'pos'},
#  {'name': 'Janet', 'message': 'Scott added Janet', 'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': 'Thanks Giuseppe and Michele',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe', 'message': 'Emoji', 'sentiment': 'neutral'},
#  {'name': 'Noa',
#   'message': 'I have just driven past 7 Colinton and their dog is outside the gate trying to get in. No one answers the bell. I called it in to CAP to call the owner. These dogs are always left outside to run in the street???',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': 'Hi Neighbours, hope everyone is having a good Saturday.. is the music from the recreation center disturbing anyone else? Thanks Scott',
#   'sentiment': 'neutral'},
#  {'name': 'Debby van Zyl',
#   'message': 'JHB residents could face level 3 water restrictions',
#   'sentiment': 'neutral'},
#  {'name': 'Loryn Sevel',
#   'message': 'Call it in to be checked out',
#   'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': 'Thanks. I did Call it in',
#   'sentiment': 'pos'},
#  {'name': 'Giuseppe',
#   'message': "Please inform all contacts from your list not to open a video called the 'Dance of the Hillary'. It is a virus that formats your mobile. Beware it is very dangerous. They announced it today on BBC radio. Fwd this msg to as many as you can!",
#   'sentiment': 'neg'},
#  {'name': 'Justin', 'message': 'It is a hoax', 'sentiment': 'neutral'},
#  {'name': 'Giuseppe', 'message': 'OR Tambo right now', 'sentiment': 'neutral'},
#  {'name': 'Gosia', 'message': 'Hectic!!!', 'sentiment': 'neg'},
#  {'name': 'Dawid',
#   'message': "That's still not nearly as bad as Dudu Myeni...",
#   'sentiment': 'neg'},
#  {'name': 'Melanie', 'message': 'Hallo all -', 'sentiment': 'neutral'},
#  {'name': 'Justin',
#   'message': 'There were genets in the area years ago. Lots of them. Have not seen them in a long time',
#   'sentiment': 'neutral'},
#  {'name': 'Gosia',
#   'message': "Yes, they are. I'm in Judy and have the genet living in our roof during winter.... he sets off many alarms and drives my daschunds mad.... but keeps our house rat free..... don't like his night time hunting though... sounds are terrible!!!",
#   'sentiment': 'neg'},
#  {'name': 'Melanie',
#   'message': "As rough as that sounds I think it's absolutely awesome - a good sign 😊 thanks for the confirm!",
#   'sentiment': 'pos'},
#  {'name': 'Scott',
#   'message': "Have also spotted a Genet up and down a tree at our bedroom during the night, also hunts on the roof, now that we have dogs haven't seen it for a while..",
#   'sentiment': 'neutral'},
#  {'name': 'Gosia',
#   'message': "We love it, he's beautiful or she 😉",
#   'sentiment': 'pos'},
#  {'name': 'Melanie', 'message': '👍🏻', 'sentiment': 'pos'},
#  {'name': 'Kim McCormick',
#   'message': "I saw what I thought was a mongoose in our driveway, but judging by this conversation, I think it was a genet. I'm on Alma. We also saw one crossing South last night. My husband actually said he thought it was a genet and I told him that we don't get them in the city. 😖",
#   'sentiment': 'neutral'},
#  {'name': 'Kerry Levy', 'message': "That's so cool.", 'sentiment': 'pos'},
#  {'name': 'Keith Jones',
#   'message': 'We have the genet either passing through or hunting - seen him a few times as well.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Warren, was that taken at your house?',
#   'sentiment': 'neutral'},
#  {'name': 'Warren Sidersky', 'message': 'Yes', 'sentiment': 'neutral'},
#  {'name': 'Justin', 'message': 'Great photo!', 'sentiment': 'pos'},
#  {'name': 'Melanie',
#   'message': "Really awesome to know they're still around.",
#   'sentiment': 'pos'},
#  {'name': 'States',
#   'message': 'I have seen this passing through my front yard from 34. I thought what an ugly cat Last myt i was.abt to ask what is a ganet. Thanx for sharing very educative.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim', 'message': 'Wow 😊', 'sentiment': 'pos'},
#  {'name': 'States',
#   'message': 'Kim not funny. Timmins Ontario. We have bears and wolves.',
#   'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'Toronto u find squirels on most trees.',
#   'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'I dont rember seeing cats in Nouvelle Caledonie. Merci.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': "What do you mean 'Kim not funny'... I was being serious. I think the pic is wow.",
#   'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'Same here. Like i said educative.',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "I think it's amazing and thanks for the explanation as to why my dogs sometimes go insane under large trees in the middle is the night when there are no signs of birds in the trees. Now I know what to look for.",
#   'sentiment': 'pos'},
#  {'name': 'Melanie',
#   'message': "That pic is insane Warren. Was so taken aback at what I thought I was seeing didn't even think to attempt a pic. Hopefully it will become a regular - happy to share my garden with it!",
#   'sentiment': 'pos'},
#  {'name': 'States',
#   'message': 'From FNB; ABSA; Capitec; Nedbank..........',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'This has been going around for years. The banks confirmed that it is a hoax.',
#   'sentiment': 'neg'},
#  {'name': 'States', 'message': 'Thanks.', 'sentiment': 'pos'},
#  {'name': 'States',
#   'message': 'http://www.iol.co.za/news/south-africa/banks-warn-of-reverse-pin-email-hoax-307687',
#   'sentiment': 'neutral'},
#  {'name': 'Angie Makwetla',
#   'message': 'What is the hoax? Does the reverse pin work or not?',
#   'sentiment': 'neutral'},
#  {'name': '~\rStates',
#   'message': 'This has been going around for years. The banks confirmed that it is a hoax.',
#   'sentiment': 'neutral'},
#  {'name': '~\rStates',
#   'message': 'Just a made up story.',
#   'sentiment': 'neutral'},
#  {'name': 'Vishal Deeplaul',
#   'message': 'All please be reminded of the 94.7 Cycle challenge this sunday where much of the roads in joburg will be impacted. Please use the app the assist with any travel that you may need to do on Sunday.',
#   'sentiment': 'pos'},
#  {'name': '~\rBernadette Phillips',
#   'message': 'Thanks for the reminder 😃',
#   'sentiment': 'pos'},
#  {'name': 'Pat Khoza',
#   'message': 'Thank you so much Visual for the reminder! !',
#   'sentiment': 'pos'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Anyone needing an exceptional part time domestic / child care?',
#   'sentiment': 'neutral'},
#  {'name': '~\rDawid',
#   'message': 'Hi. Looking for a car guard for Saturday the 26th, please direct message me if you any contacts. Tx.',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'Hi Dawid, you can also hire a 7 arrows guard if you want..',
#   'sentiment': 'pos'},
#  {'name': 'Andre',
#   'message': 'Is there a party in town??',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'Xmas party in the park..',
#   'sentiment': 'neutral'},
#  {'name': 'Andre', 'message': 'Nice one', 'sentiment': 'pos'},
#  {'name': 'Andre', 'message': "Shame it's raining though", 'sentiment': 'neg'},
#  {'name': 'Andre', 'message': 'But guess we need it', 'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "We've complained about these loud year end functions for 2 years now but they think the rest of the community are happy with the loud music. Please if anyone else isn't happy with it contact Elsie.",
#   'sentiment': 'neg'},
#  {'name': 'Rudolph', 'message': 'I sent a complaint', 'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'I sms a complaint. Thank you for the number.',
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': "I've just spoken to Elsie in the phone. She's asked that we draft an official letter so that it can be escalated. I'll draft the letter, but I need signatures of all the complainants. Would you be willing to sign?",
#   'sentiment': 'neutral'},
#  {'name': 'Rudolph', 'message': 'Sure', 'sentiment': 'pos'},
#  {'name': 'John S',
#   'message': 'Poss best that MMAP gains consensus from its members and then sign as a "Group" by means of a Director signature - this affects us all after all.....',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Sounds like a great idea John. Thanks.',
#   'sentiment': 'pos'},
#  {'name': 'John S',
#   'message': 'No prob Kimble - 100 plus members of an Org backing up a single "complaint" beats multiple individual complaints every time.... 😉',
#   'sentiment': 'pos'},
#  {'name': 'Scott', 'message': 'Thanks Neighbours..', 'sentiment': 'pos'},
#  {'name': 'Ron',
#   'message': 'Please add 0834593656 Maria to this list. Thx',
#   'sentiment': 'neutral'},
#  {'name': 'Maria Meiring',
#   'message': 'Scott added ~\nMaria Meiring',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Wonderful thank you',
#   'sentiment': 'pos'},
#  {'name': 'Graeme',
#   'message': 'Went to remove illegal advertising from cnr Blackford and Ridgeway. Looks like someone beat me to it. Thank you.',
#   'sentiment': 'pos'},
#  {'name': 'Ross Smith',
#   'message': 'Cap on 702 bad pr. Apologies wrong forum.',
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': "Does anyone know the legalities around noise levels in a residential area? I'm in the process of writing the official letter of complaint for the events in the park.",
#   'sentiment': 'neutral'},
#  {'name': 'Jon',
#   'message': 'Theres the Gauteng Noise Control Regulations that prohibit noise disturbance and noise nuisance. I can send them to you a bit later and provide some guidance.',
#   'sentiment': 'pos'},
#  {'name': 'Kim',
#   'message': "Hi everyone. Please can I make an appeal... Please drive slowly through the neighborhood. Unfortunately, a car in front of me just hit a baby genet in Stuart Avenue. I stopped to help it but it died. There is another baby that ran up a tree outside one of the houses. The person who hit the baby also stopped to help. I'm not sure where the mom is.",
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick', 'message': 'So sad!!', 'sentiment': 'neg'},
#  {'name': 'Kim', 'message': "I'm so heartsore.", 'sentiment': 'neg'},
#  {'name': 'Andantê Wiehahn', 'message': '😢', 'sentiment': 'neg'},
#  {'name': 'Bridget Radebe',
#   'message': 'Hi all. Just wondering if anyone else other than Ekow and I are finding their boom remote does not work for exiting from Lynton Road?',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "Hi Bridget, ours seem to be fine, I'll check tomorrow morning and let you know if it's not working.. maybe replace the batteries? Not sure if that might help..",
#   'sentiment': 'neutral'},
#  {'name': 'Santhuri',
#   'message': 'Hi all. Who can we contact to tar the pothole by the ridgeway boom gate?',
#   'sentiment': 'neutral'},
#  {'name': 'Warren Sidersky',
#   'message': 'http://www.jra.org.za/find-and-fix-mobile-app',
#   'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': "Thanks Scott. The exit and entry for Ridgeway work as well as entry for Lynton. It's just the exit at Lynton. Which does not work.",
#   'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': "So I don't think it's the batteries.",
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'Hi Neighbours, does anyone know of a domestic worker that will be able to help us for a few days in the next 2/3 weeks? Many thanks Scott',
#   'sentiment': 'neutral'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Yes i have, will whatsup you 😀',
#   'sentiment': 'pos'},
#  {'name': 'Scott', 'message': 'Thanks Bernadette.. 😉', 'sentiment': 'pos'},
#  {'name': 'Bridget Radebe', 'message': 'Hi Scott', 'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': 'Try an agency called SA Nanny as well.',
#   'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': 'Will send you contact on whatsapp',
#   'sentiment': 'neutral'},
#  {'name': 'Scott', 'message': 'Thanks Bridget!!', 'sentiment': 'pos'},
#  {'name': 'Melanie',
#   'message': 'Melanie changed their phone number to a new number. Tap to message or add the new number.',
#   'sentiment': 'neutral'},
#  {'name': 'Tembiwe',
#   'message': "Hello. I'm looking for a domestic worker who is available to work some days during the 2 week festive break; if anyone knows of someone. Thanks, Tembi",
#   'sentiment': 'neutral'},
#  {'name': '+267 75 605 452',
#   'message': '+267 75 605 452 changed their phone number to a new number. Tap to message or add the new number.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Did anyone claim the dog?',
#   'sentiment': 'neutral'},
#  {'name': 'Annmarie',
#   'message': 'Took it to the vet. He had a chip and they said they would contact owners',
#   'sentiment': 'pos'},
#  {'name': 'Kim McCormick',
#   'message': 'Ok great. Thanked',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick', 'message': 'Thanks.', 'sentiment': 'pos'},
#  {'name': 'Kim McCormick',
#   'message': 'Is the noise in the park bothering anyone else?',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "It's driving us nuts too Kim... for those who are also bothered please email the DA councillor on wernersmit94@gmail.com to complain..",
#   'sentiment': 'neg'},
#  {'name': '~\nArno',
#   'message': 'Is anyone else bothered by the loud music in the park as well?? Surely this is not acceptable??',
#   'sentiment': 'neg'},
#  {'name': '~\nKim McCormick',
#   'message': "It's insane. Our windows are vibrating. The music has just been put louder.",
#   'sentiment': 'neg'},
#  {'name': 'Vishal Deeplaul',
#   'message': 'Agree. .... but it is the festive season',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "Who cares about festive season. Sorry. But I don't se why I have to celebrate at the same time as everyone in the park. I most definitely do not enjoy the music the park folks enjoy. If you think it's festive to hear it over your TV enoy... I dont",
#   'sentiment': 'neg'},
#  {'name': '~\nKim McCormick',
#   'message': "Festive season or not, it shouldn't be acceptable to play music this loudly. There's having a good time and then there's crossing the line.",
#   'sentiment': 'neg'},
#  {'name': '~\nArno',
#   'message': 'Festive season can also be done at more acceptable levels. This is not acceptable!! We have to take action against this!!',
#   'sentiment': 'neg'},
#  {'name': 'Justin',
#   'message': 'This is crazy , can hear it from top of ridgeway drive',
#   'sentiment': 'neg'},
#  {'name': 'Justin',
#   'message': "Think it's worth calling cops",
#   'sentiment': 'neg'},
#  {'name': 'Vishal Deeplaul', 'message': 'Support', 'sentiment': 'pos'},
#  {'name': '~\rArno',
#   'message': 'We called the cops last year when a party kept in after 21h00...2 eventually arrived and were threatened by the drunken party goers to the point that they went back to Sandton police station to get reinforcements...',
#   'sentiment': 'neg'},
#  {'name': '~\rRudolph',
#   'message': 'How far is that petition - We all need to sign and get some ground rules in place for the park',
#   'sentiment': 'neutral'},
#  {'name': '~\rArno',
#   'message': 'But please we would welcome if someone else also phones the cops...they think by now we are the only grumpy people in the area...',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': "The petition is in process and should be finalized this coming week, in the meantime please email Werner to complain, we have to push every angle to try sort this out, we've been fighting this now for two years and it need to stop, the bylaws are being ignored by the recreation center...",
#   'sentiment': 'neg'},
#  {'name': '~\rDebby van Zyl',
#   'message': 'I emailed Werner earlier on today.',
#   'sentiment': 'neutral'},
#  {'name': '~\rArno',
#   'message': 'What everyone needs to consider as well as that there are huge amounts of alcohol consumed at these events and then the drunken drivers leave through our neighborhood to go home,endangering our families and our neighborhood...one day one of us will be run over or crashed into by a drunk driver leaving these parties...',
#   'sentiment': 'neg'},
#  {'name': '~\rRudolph',
#   'message': 'I have emailed Werner already',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'I have emailed Were and I also sent two sms to Elise.',
#   'sentiment': 'neutral'},
#  {'name': '~\rArno',
#   'message': "I've been in contact with Werner on the noise issues in the park. Werner has agreed to meet with us the residents in January to discuss the way forward between the park and residents. It would be great if everyone who has concerns on this join us then. Details will be sent in January.",
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe', 'message': 'Great', 'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe', 'message': 'Thank you', 'sentiment': 'pos'},
#  {'name': '~\rStates', 'message': 'Wow', 'sentiment': 'neutral'},
#  {'name': '~\rNoa', 'message': 'Insane', 'sentiment': 'neutral'},
#  {'name': '~\rLoryn Sevel',
#   'message': 'What on earth was that ???',
#   'sentiment': 'neg'},
#  {'name': '~\rNoa',
#   'message': 'Fireworks next door me',
#   'sentiment': 'neutral'},
#  {'name': '~\rLoryn Sevel', 'message': 'Ok👍🏻', 'sentiment': 'pos'},
#  {'name': '~\rKim McCormick',
#   'message': "Flip. That's unnecessary. Was it not in the park?",
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'That was totally unacceptable. A party.... no problem but the firework at this time of night .... not on.',
#   'sentiment': 'neg'},
#  {'name': '~\rNoa', 'message': 'No on Ratcliff', 'sentiment': 'neutral'},
#  {'name': '~\rArno',
#   'message': 'Nope it came from our neighborhood',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Behind Murray. I think on judy',
#   'sentiment': 'neutral'},
#  {'name': '~\rStephen Smith',
#   'message': 'What the heck? That is totally unnecessary. \n',
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'They stuck a notice on our gate to day they having a party. Ok. Thank you but the crackers scared the heck out of my dog and woke us all up with our hearts racing. Very uncalled for',
#   'sentiment': 'neg'},
#  {'name': '~\rLoryn Sevel',
#   'message': "Let's all just be grateful it was only fireworks",
#   'sentiment': 'neutral'},
#  {'name': '~\rKim',
#   'message': "Aren't fireworks in residential areas illegal? A party is one thing but that was totally unacceptable. \n",
#   'sentiment': 'neg'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Yes fireworks in residential area are illegal.',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "I can't explain to my little dog what the noise was. So I'm not grateful for anything... sorry.",
#   'sentiment': 'neg'},
#  {'name': '~\rLouis', 'message': '~\rLouis left', 'sentiment': 'neutral'},
#  {'name': '~\rStates',
#   'message': "Hi all please be advised as with immediate effect on radio this morning, Any motorist talking on mobile phone while driving, your phone will be taken away and u will have to pay a R2500-00 fine to get it back, Also if u haven't got your drivers licence with you u will be taken into custody AND PAY 1000-00 before they release you Please send to all famiy and friends to safe guard",
#   'sentiment': 'neutral'},
#  {'name': 'Roxanne Casey', 'message': 'Hi All,', 'sentiment': 'neutral'},
#  {'name': 'Justin', 'message': 'Thanks Patrik', 'sentiment': 'pos'},
#  {'name': 'Loryn Sevel', 'message': 'Thank you!', 'sentiment': 'pos'},
#  {'name': 'Angie Makwetla',
#   'message': "Hi all please be advised as with immediate effect on radio this morning, Any motorist talking on mobile phone while driving, your phone will be taken away and you will have to pay a R2500-00 fine to get it back, Also if you haven't got your drivers licence with you you will be taken into custody AND PAY 1000-00 before they release you Please send to all family and friends to safe guard",
#   'sentiment': 'neutral'},
#  {'name': 'Bridget Radebe',
#   'message': 'Does that fine apply if you have a hands free kit for your phone?',
#   'sentiment': 'neutral'},
#  {'name': 'Dr Mark Wertheimer',
#   'message': 'Has the authenticity of this been verified. It has gone viral despite some aspects of it seeming to be legally incorrect',
#   'sentiment': 'neutral'},
#  {'name': 'Janet Byrne',
#   'message': 'Having tried unsuccessfully the last two mornings to flag down our noisy early morning motorbiker, he felt compelled to make a u turn this morning (who knew the power of a raised middle finger). I explained that the whole neighbour is annoyed by the early morning disturbance. He was unaware of this?? and has promised to throttle back from south road to rivonia. I will be away from today and would appreciate feedback as I would follow up again. He says he gets from town to Bowling in 8 minutes and will now give himself extra time to driver with manners past our suburb. No number plates either. Hope u all have a happy and peaceful xmas.',
#   'sentiment': 'neutral'},
#  {'name': 'John S',
#   'message': 'Thanks Janet for your initiative - I spoke to SAPS Sandton, and they stated they need number plate details in order to verify and "pay him a visit" - JMPD were not interested at all, and SAPS say that they can not set up a roadblock due to jurisdiction issues - SAPS stated that what he was doing constituted a criminal offense, so if he continues, I am only too happy to join you in flagging him down again..... Contact person at SAPS is Constable Lungi Mbatha - if anyone else wishes to escalate officially, I am only too happy to share her number - she was most understanding and helpful',
#   'sentiment': 'neutral'},
#  {'name': 'Janet Byrne',
#   'message': "Thanks John. Let's hope he keeps his word.",
#   'sentiment': 'pos'},
#  {'name': 'Andantê Wiehahn',
#   'message': "Janet, THANK YOU so much! We'll keep an ear out for him while you are away... hopefully he keeps to his word.",
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Thank you both and well done.',
#   'sentiment': 'pos'},
#  {'name': 'Steven Blend',
#   'message': 'Constable Lungi Mbatha has been a wonderful resource at SAPS for our sector for years.',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': 'Just a reminder to all.',
#   'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'Police Questioning a Robber:',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe', 'message': '\n', 'sentiment': 'neutral'},
#  {'name': 'Pat Khoza',
#   'message': 'Thanks Connie for that piece over information! !',
#   'sentiment': 'pos'},
#  {'name': 'Graeme',
#   'message': 'Silver Mercedes, 2 bm just tried to break into house in black ford.',
#   'sentiment': 'neg'},
#  {'name': 'Graeme',
#   'message': 'Blackford, headed south on bowling.',
#   'sentiment': 'neutral'},
#  {'name': 'Saaleha Motala',
#   'message': 'Which house on blackford?',
#   'sentiment': 'neutral'},
#  {'name': 'Gosia',
#   'message': 'Hectic... were they stopped???',
#   'sentiment': 'neutral'},
#  {'name': 'Graeme',
#   'message': "No left as soon as they saw me looking at them. Unfortunately didn't get the registration number.",
#   'sentiment': 'neg'},
#  {'name': 'Graeme',
#   'message': 'Phoned calls centre and flagged down both adt and cap.',
#   'sentiment': 'neutral'},
#  {'name': 'Graeme',
#   'message': 'Sorry, wrong group, will repost on the security group.',
#   'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'This is arguably the most beautiful story I have received on whatsapp! READ... A lady worked at a meat distribution factory...',
#   'sentiment': 'pos'},
#  {'name': 'Scott',
#   'message': 'Hi Community, please keep an eye out for an old Rottweiler called Babe, she went missing yesterday afternoon from Alma road...',
#   'sentiment': 'neg'},
#  {'name': 'Gosia', 'message': 'Noted', 'sentiment': 'neutral'},
#  {'name': 'States',
#   'message': 'Did she contacted SPCA Malboro',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'She tried last night but only an answering machine and is trying again now. Many thanks',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': 'Hi All, the Rottwieler has been found (someone took her to the Manor vet), many thanks, have a wonderful day!',
#   'sentiment': 'pos'},
#  {'name': 'Kim', 'message': 'Great news 🙂🙂', 'sentiment': 'pos'},
#  {'name': 'States', 'message': 'Siyabonga', 'sentiment': 'neutral'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Could the person who speeds up and down Ridgeway Drive in a blue Audi cabriolet please do your speeding at Kyalami race track and not in our residential area where kids and animals might cross the road !!!!!!',
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': 'Hello. Happy New Year everyone.',
#   'sentiment': 'pos'},
#  {'name': 'Kim McCormick',
#   'message': "Is anyone else's power off? We're on Alma.",
#   'sentiment': 'neutral'},
#  {'name': 'Jonathan',
#   'message': 'I have power on Alma.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': "There is an alsatian loose on Colinton. I've tried ringing the bell of the house he belongs to but no answer. Can't see a number on the house but is the third last house on the left before you get to Ratcliffe. 😣😣😣😣😣",
#   'sentiment': 'neg'},
#  {'name': 'Kim',
#   'message': "Does anyone have these people's number so I can call them 😢",
#   'sentiment': 'neg'},
#  {'name': 'Noa',
#   'message': 'I usually call CAP and they call them. It is always left outside.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': "Thanks. I've called them",
#   'sentiment': 'neutral'},
#  {'name': 'States', 'message': '🚨Urgent...', 'sentiment': 'neutral'},
#  {'name': 'Justin',
#   'message': 'This is an old scam that only worked on very old pabx system not relevant to mobile phones',
#   'sentiment': 'neutral'},
#  {'name': 'Jon',
#   'message': 'Only risk is if you call back then it can cost you dialling the international no.',
#   'sentiment': 'neutral'},
#  {'name': 'States', 'message': 'Thanks neighbors.', 'sentiment': 'pos'},
#  {'name': 'States',
#   'message': "Armscor is desperately looking for engineering students to fund....let no deserving child stay at home because this message didn't get to them.",
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': 'Can anyone in Colinton see if that doggy is back inside his yard or if he is still outside the gate?',
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "Hi Kim I found some details for the owner, tried to call but it's on voicemail and sent an email...",
#   'sentiment': 'neutral'},
#  {'name': 'Kim',
#   'message': "Thanks so much.  I'm so worried about him.  My daughter just woke up so one lunch done I think I'll go Check on him/her",
#   'sentiment': 'neutral'},
#  {'name': 'Scott',
#   'message': "Thanks for all you're doing, will keep trying to get hold of the owner",
#   'sentiment': 'pos'},
#  {'name': 'Kim', 'message': 'Thanks.  Appreciate it', 'sentiment': 'pos'},
#  {'name': 'Kim',
#   'message': "Came to give doggy some water.... Happy to report that he/she is back inside the property.  Still doesn't seem like anyone is home so not sure how he/she got back In",
#   'sentiment': 'pos'},
#  {'name': 'Scott',
#   'message': "Great news, thanks Kim. Apparently he/she gets out often and somehow always gets back in... don't know how...",
#   'sentiment': 'neutral'},
#  {'name': 'Vishal Deeplaul',
#   'message': "Armscor is desperately looking for engineering students to fund....let no deserving child stay at home because this message didn't get to them.",
#   'sentiment': 'pos'},
#  {'name': '~\rStates',
#   'message': 'Good morning If you know of anyone interested in studying medicine this year and needs funding, please forward their name and contact number to Hlammy Shimange +27 83 945 8436 REQUIREMENTS:',
#   'sentiment': 'pos'},
#  {'name': '~\rDorothy (Dot) Johnson',
#   'message': '\rScott added ~\rDorothy (Dot) Johnson',
#   'sentiment': 'neutral'},
#  {'name': '~\rKim McCormick',
#   'message': "Hi All. If anyone is looking for a domestic worker, ours is available on Thursday's. She's very reliable and loyal. If you're interested, please message me directly.",
#   'sentiment': 'pos'},
#  {'name': '~\rJohn S',
#   'message': 'Thanks Justin for the house robberies modus operandi post in the Security Group - would it be possible for us to list all Eskom sub-stations for Alma / Stuart / Lynton / Ridgeway and environs so that we have a "go to" person in the event of power failures? I am happy to volunteer to check any sub-stations close to Morningside Villas if required.',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': 'Yes, I think it would be a good idea for us to map it out. If anyone is keen to assist. I will create a mini wa group and message me to join',
#   'sentiment': 'pos'},
#  {'name': '~\rNeill',
#   'message': '\rScott added ~\rNeill',
#   'sentiment': 'neutral'},
#  {'name': '~\rFe',
#   'message': '\r~\rBernadette Phillips added ~\rFe',
#   'sentiment': 'neutral'},
#  {'name': '~\rTinus Human',
#   'message': '\r~\rBernadette Phillips added ~\rTinus Human',
#   'sentiment': 'neutral'},
#  {'name': 'Andre',
#   'message': 'Good morning and hope everyone is having a good start to their day! One of the electric poles on Murray avenue requires repairs. Who should I direct this query to? Thank you in advance.',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': "Please get your burglar alarm under control it's now going off for the the 5th or 6th time today.",
#   'sentiment': 'neg'},
#  {'name': 'John S',
#   'message': 'I see that there is a guard based at the Lynton Road boom - is there an issue that we should all be aware of?',
#   'sentiment': 'neutral'},
#  {'name': 'Caron Hagues',
#   'message': 'My Gardener, Frank, looking for work. Available Tuesday, Wednesday, Thursday. Should you be interested in employing him on any of those days, please contact me.',
#   'sentiment': 'neutral'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Excellent domestic / child carer with solid references available on Tuesdays & Thursdays. Melita lives on our premises in Morningside Manor.',
#   'sentiment': 'neutral'},
#  {'name': 'Debby van Zyl',
#   'message': 'Huge overflow of water from a manhole next to house number 349 Ratcliffe Rd. Is anyone aware of it? Can I call JHB Water?',
#   'sentiment': 'neg'},
#  {'name': 'Steven Blend',
#   'message': 'Yes please do call Debby - thanks Steven Blend',
#   'sentiment': 'neutral'},
#  {'name': 'Debby van Zyl',
#   'message': 'Call logged. Unfortunately no reference number. System down',
#   'sentiment': 'neg'},
#  {'name': 'Bridget Radebe', 'message': 'Thanks Debbie', 'sentiment': 'pos'},
#  {'name': 'Kim',
#   'message': 'No 21 ratcliffe....  Your gate is open and your doggy is in the road.  just letting you know......',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Hi. Has anyone else received an invoice from CAP? It seems really dodgy to me, as we pay our security company and MMAP directly?',
#   'sentiment': 'neg'},
#  {'name': 'Angie Makwetla',
#   'message': 'The dog video is amazing. Peaceful co-existence in action.',
#   'sentiment': 'pos'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'At the end of the financial year you will receive a section 18 certificate from CAP for the money you pay towards the boom. It is a certificate you attach to your tax return and you claim the full amount of it back from your taxes due as a donation. There is absolutely nothing fishy about it at all. I have been receive my certificate and claiming it legally for years.',
#   'sentiment': 'neutral'},
#  {'name': '\nKim McCormick',
#   'message': "Hi Mich. it's very odd though, because it's not the money that we contribute to CAP, it's the monthly bill of what we pay the security company. It's not the annual amount we pay to CAP. I'll give them a call though. Thanks.",
#   'sentiment': 'neutral'},
#  {'name': 'Michelle & Giuseppe',
#   'message': 'Let me know if it pans out.',
#   'sentiment': 'neutral'},
#  {'name': 'Pat  Khoza',
#   'message': "I also received the invoice which I don't understand! !!!",
#   'sentiment': 'neg'},
#  {'name': 'Ekow',
#   'message': "We also received an odd invoice for 'arrears'",
#   'sentiment': 'neg'},
#  {'name': 'Justin',
#   'message': "I suspect it's a mistake",
#   'sentiment': 'neutral'},
#  {'name': 'Justin',
#   'message': "Contact jacqueline@capgroup.org.za to see why it's being sent to you",
#   'sentiment': 'neutral'},
#  {'name': 'Pat  Khoza',
#   'message': 'shocking!!!!!!!!!!!!!!!!!',
#   'sentiment': 'neg'},
#  {'name': 'Bridget Radebe',
#   'message': 'Why is this not evidence to get them back behind bars?',
#   'sentiment': 'neg'},
#  {'name': 'Justin',
#   'message': 'Anyone know a good electrician?',
#   'sentiment': 'neutral'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Recommends Stephen from Top Notch for services, having used him several times.',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': 'Expresses gratitude to Trudi.',
#   'sentiment': 'pos'},
#  {'name': '~\rAndre',
#   'message': 'Inquiring about a power outage on Murray avenue.',
#   'sentiment': 'neutral'},
#  {'name': 'Justin',
#   'message': 'Confirms power outage in Ridgeway too.',
#   'sentiment': 'neutral'},
#  {'name': '~\rNoa',
#   'message': 'Reports power outage in Ratcliff as well.',
#   'sentiment': 'neutral'},
#  {'name': 'Justin',
#   'message': 'Reports power back on in Ridgeway.',
#   'sentiment': 'pos'},
#  {'name': '~\rAndre',
#   'message': 'Confirms power restoration on Murray avenue.',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': 'Reports power outage on Ridgeway, asking if others are affected.',
#   'sentiment': 'neutral'},
#  {'name': '~\rRudolph',
#   'message': 'Confirms power outage on Murray.',
#   'sentiment': 'neutral'},
#  {'name': '~\rSaaleha Motala',
#   'message': 'Confirms power outage on Ratcliffe as well.',
#   'sentiment': 'neutral'},
#  {'name': 'Desi', 'message': 'Colinton out', 'sentiment': 'neg'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Cnr ridgeway & Murray fine - still on.',
#   'sentiment': 'pos'},
#  {'name': 'Kim McCormick', 'message': 'Alma is fine.', 'sentiment': 'pos'},
#  {'name': 'John S', 'message': 'Morn Villas is on', 'sentiment': 'pos'},
#  {'name': 'Debby van Zyl',
#   'message': 'Anyone called Eskom?',
#   'sentiment': 'neutral'},
#  {'name': 'Debby van Zyl',
#   'message': 'Called Eskom, no planned outage. Logged the power outage.',
#   'sentiment': 'neutral'},
#  {'name': 'Desi',
#   'message': 'Eskom guys came to see me. Someone stole the earth cable at substation. They fixing it now. +-45mins',
# ...
#   'message': 'Thanks Gosia and Lillian, have logged a complaint.',
#   'sentiment': 'neutral'},
#  {'name': 'Tinus Human',
#   'message': 'Tinus Human left',
#   'sentiment': 'neutral'},
#  {'name': 'Andantê Wiehahn',
#   'message': 'FYI re party in Ridgeway on July 1st.',
#   'sentiment': 'neutral'},
#  {'name': 'Memeh',
#   'message': "Memeh joined using this group's invite link",
#   'sentiment': 'neutral'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Anyone needing a good plumber at very reasonable rates? I can recommend Simon. Pvt msg me for his nr.',
#   'sentiment': 'pos'},
#  {'name': 'Debby van Zyl',
#   'message': "Can someone please help me with a contact at JHB Water/COJ. We have been incorrectly billed since the meter was changed in March. We've been to JHB water offices and COJ with no help. This has been going on for 4mths now. We simply need someone to come out and read the meter so we can be correctly billed.",
#   'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': "Hi Debbie. Whoever handles their twitter account is in the ball. When you post your tweet, include the call no that you logged. They then escalate. I've done that on more than one occasion and it's been sorted relatively quickly.",
#   'sentiment': 'pos'},
#  {'name': 'Debby van Zyl',
#   'message': 'Will do. Thanks Kimble.',
#   'sentiment': 'pos'},
#  {'name': 'Nomvuyo',
#   'message': 'Requesting a referral or recommendation for a music production company/house for her son who needs to do job shadowing for a school assignment.',
#   'sentiment': 'neutral'},
#  {'name': 'Priyal',
#   'message': 'Advertising that Miriam, their domestic, is looking for part-time work and praising her qualities.',
#   'sentiment': 'pos'},
#  {'name': 'Arno',
#   'message': 'Informing about a planned water interruption on 19 July.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim Silber',
#   'message': 'Expressing gratitude to Arno.',
#   'sentiment': 'pos'},
#  {'name': 'Andantê Wiehahn',
#   'message': 'Expressing gratitude.',
#   'sentiment': 'pos'},
#  {'name': 'Lillian',
#   'message': 'Expressing gratitude and appreciation.',
#   'sentiment': 'pos'},
#  {'name': 'Keith Jones',
#   'message': 'Informing that the planned water shutdown was cancelled according to an email from Joburg Water.',
#   'sentiment': 'neutral'},
#  {'name': 'Djk Lumu',
#   'message': 'Thanking for the update on the water situation.',
#   'sentiment': 'pos'},
#  {'name': 'Matso at Rera Language School',
#   'message': 'Joined the group using the invite link.',
#   'sentiment': 'neutral'},
#  {'name': 'Caron Hagues',
#   'message': 'Thanking for the update on the water situation.',
#   'sentiment': 'pos'},
#  {'name': 'TamiTheTurtle🐢',
#   'message': "joined using this group's invite link",
#   'sentiment': 'neutral'},
#  {'name': 'Paul Congruence',
#   'message': 'Wow, powerful stuff! Thnx for sharing Vishal.',
#   'sentiment': 'pos'},
#  {'name': 'Andre',
#   'message': "Is anyone's Telkom service down?",
#   'sentiment': 'neutral'},
#  {'name': 'TamiTheTurtle🐢',
#   'message': 'Yes, ours is down.',
#   'sentiment': 'neg'},
#  {'name': 'Andre',
#   'message': "Trying to phone them but no luck. Sent a tweet to them. Let's see",
#   'sentiment': 'neg'},
#  {'name': 'Andre',
#   'message': 'Saw this. Maybe the issue',
#   'sentiment': 'neutral'},
#  {'name': 'Piotr',
#   'message': 'Is anyone in Morningside Manor with Afrihost for Fibre? If yes, are you happy?',
#   'sentiment': 'neutral'},
#  {'name': 'Paul Congruence',
#   'message': 'Yep, started 1 July uncapped. So far so good.',
#   'sentiment': 'pos'},
#  {'name': 'Kim', 'message': 'Wrong group?', 'sentiment': 'neutral'},
#  {'name': 'Arno',
#   'message': 'Is anybody having slow connectivity issues with Telkom fiber?',
#   'sentiment': 'neg'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Yes we also experiencing slow connectivity.',
#   'sentiment': 'neg'},
#  {'name': 'Kelly Arnold',
#   'message': "Morning, looking for a recommendation for a trustworthy carpet cleaner please. We've used 2 different companies and both times had items stolen. Thanks!",
#   'sentiment': 'neutral'},
#  {'name': 'Odette Jones',
#   'message': 'Mr Steam - 0115680400',
#   'sentiment': 'neutral'},
#  {'name': 'Debby van Zyl',
#   'message': 'Albert is very reliable and trustworthy. Been using his services for many years.',
#   'sentiment': 'pos'},
#  {'name': 'Kim McCormick',
#   'message': "We've used a company called Fluffy Carpets for years. Think that they do amazing work and really well priced. Have never had any issues.",
#   'sentiment': 'pos'},
#  {'name': 'Kelly Arnold',
#   'message': 'Thank you everyone. Appreciate it 😊👍🏻',
#   'sentiment': 'pos'},
#  {'name': 'Ekow', 'message': 'We use Fluffy as well', 'sentiment': 'pos'},
#  {'name': 'X1O',
#   'message': 'Power off in Minto...anybody else?',
#   'sentiment': 'neg'},
#  {'name': 'Trudi Du Toit', 'message': '19 Murray off too', 'sentiment': 'neg'},
#  {'name': 'X1O', 'message': 'Thanks...', 'sentiment': 'neutral'},
#  {'name': 'John S',
#   'message': 'Morningside Villas off as well - also for +-5mins this morning around 10am',
#   'sentiment': 'neg'},
#  {'name': 'John S',
#   'message': 'From one of our Directors - "Hi everyone just spoke to Eskom. This was not a planned outage - they are currently working on the problem but are unable to advise when we will have power again."',
#   'sentiment': 'neg'},
#  {'name': 'John S', 'message': 'Power on at MV', 'sentiment': 'pos'},
#  {'name': 'Ross Smith', 'message': 'Out Lynton', 'sentiment': 'neg'},
#  {'name': 'Jenny Rahme', 'message': 'Ullmann park is out', 'sentiment': 'neg'},
#  {'name': 'Jenny Rahme',
#   'message': 'Power back at the park!',
#   'sentiment': 'pos'},
#  {'name': 'Nola Brown',
#   'message': 'Anyone seen a male Jack Russell, tan and white, one ear up, one ear down? Last seen heading towards Ulman Park.',
#   'sentiment': 'neutral'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Will keep eyes open.',
#   'sentiment': 'neutral'},
#  {'name': 'Roxanne Casey',
#   'message': 'No, but we are right n st to the park so will keep an eye for him.',
#   'sentiment': 'neutral'},
#  {'name': 'Vivek',
#   'message': 'Hi anyone aware of any change in the garbage collection schedule?',
#   'sentiment': 'neutral'},
#  {'name': 'Vivek',
#   'message': 'Saw them collecting now',
#   'sentiment': 'neutral'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Hi, when they don\'t collect on a Friday then they catch up over the weekend ":)"',
#   'sentiment': 'pos'},
#  {'name': 'Vivek', 'message': 'Thank you', 'sentiment': 'pos'},
#  {'name': 'Michelle',
#   'message': 'Hi all. I have had a lady working for me on a temp basis this month while my domestic was on leave. Her name is Maria. She was employed by a family in Morningside for a long time but recently lost her job. She is sweet, but reserved, works thoroughly on her own but doesnt mind direction. She is good with kids. She lives in Kelvin ( so no transport issues) She has a son so she isnt looking for a live in position. If anyone is interested give her a call on 0618239940',
#   'sentiment': 'neutral'},
#  {'name': 'Beth',
#   'message': 'We are relocating and looking for work for our gardener Sam. He has worked for us for several years and has always shown himself to be reliable hardworking trustworthy and willing. He also has done painting and other odd jobs for us. We unreservedly recommend him. His number 0828153405',
#   'sentiment': 'pos'},
#  {'name': 'Shareen',
#   'message': 'Anybody else having a problem with their Telkom',
#   'sentiment': 'neutral'},
#  {'name': 'Kim Silber',
#   'message': 'Yes, since last Friday. Was on yesterday for a brief period and this morning technician came out, tested and said we needed a new modem.',
#   'sentiment': 'neutral'},
#  {'name': 'Giuseppe',
#   'message': 'Yes we also have a problem',
#   'sentiment': 'neutral'},
#  {'name': 'Craig Blend',
#   'message': "Hi all, does anyone in Alma Road have borehole? I want to know if it's worth drilling. I know some houses on the other side of the park have but not sure about Alma side. Tia",
#   'sentiment': 'neutral'},
#  {'name': 'Saaleha Motala',
#   'message': 'My Telkom internet is intermittent',
#   'sentiment': 'neutral'},
#  {'name': 'Keith Jones',
#   'message': 'Ours is shocking. We are going to move onto something else',
#   'sentiment': 'neg'},
#  {'name': 'Piotr',
#   'message': 'I did. Afrihost. Telkom was a joke',
#   'sentiment': 'neg'},
#  {'name': 'Stephen Smith',
#   'message': "Don't let telkom have a monopoly on fibre in the area.",
#   'sentiment': 'neg'},
#  {'name': 'Piotr', 'message': 'They are not interested.', 'sentiment': 'neg'},
#  {'name': 'Kim McCormick',
#   'message': 'Vumatel sent a mail the other day saying that they have decided to retract their plans for our area.',
#   'sentiment': 'neg'},
#  {'name': 'Scott',
#   'message': 'I think that plan was for the Alma side unfortunately.. they seem to be going forward with this side of MM...',
#   'sentiment': 'neutral'},
#  {'name': 'Desi',
#   'message': 'So is Ridgeway and Colinton road on vumas plan?',
#   'sentiment': 'neutral'},
#  {'name': 'Desi', 'message': '\n', 'sentiment': 'neutral'},
#  {'name': 'Kim McCormick', 'message': 'So sad.', 'sentiment': 'neg'},
#  {'name': 'Piotr',
#   'message': 'There is a premium in MM for Afrihost. 40 Down/20up line is more expensive than other areas offering 50/50.',
#   'sentiment': 'neg'},
#  {'name': 'Debby van Zyl',
#   'message': 'Shared a Twitter link.',
#   'sentiment': 'neutral'},
#  {'name': 'Justin', 'message': 'Reminder.', 'sentiment': 'neutral'},
#  {'name': 'Kerry Levy',
#   'message': 'Asking if booking is required for domestics.',
#   'sentiment': 'neutral'},
#  {'name': 'Justin', 'message': 'No booking required.', 'sentiment': 'pos'},
#  {'name': 'TamiTheTurtle',
#   'message': "Questioning if it's only for domestic workers.",
#   'sentiment': 'neutral'},
#  {'name': 'Craig Blend',
#   'message': 'Inquiring about borehole ownership.',
#   'sentiment': 'neutral'},
#  {'name': 'Roxanne Casey',
#   'message': 'No borehole, considering getting one.',
#   'sentiment': 'neutral'},
#  {'name': 'Sherwin',
#   'message': 'Mentioning a working borehole on Ratcliffe with plenty of water.',
#   'sentiment': 'pos'},
#  {'name': 'Craig Blend',
#   'message': 'Expressing gratitude.',
#   'sentiment': 'pos'},
#  {'name': 'Trudi Du Toit',
#   'message': 'Borehole on Murray',
#   'sentiment': 'pos'},
#  {'name': '~\rCraig',
#   'message': "We haven't had Telkom fibre connection since yesterday afternoon in Ratcliffe Drive. Anyone experiencing the same problem?",
#   'sentiment': 'neg'},
#  {'name': '~\rStephen Smith',
#   'message': 'During installation of the fibre, there is no way to tell which lines are active. So if the technicians are given the wrong info, they can disconnect you when installing someone else. This happened to us 4 times. (also in Ratcliffe)',
#   'sentiment': 'neg'},
#  {'name': '~\rCraig', 'message': 'Thank you', 'sentiment': 'pos'},
#  {'name': '~\rStephen Smith',
#   'message': 'They will need to send someone to check the lines',
#   'sentiment': 'neutral'},
#  {'name': '~\rKim Traill',
#   'message': 'We have very strong borehole on Colinton.',
#   'sentiment': 'pos'},
#  {'name': '~\rBernadette Phillips',
#   'message': 'Our fibre seems fine but VERY slow.',
#   'sentiment': 'neg'},
#  {'name': '~\rCaron Hagues',
#   'message': 'We have borehole (Alma). Good supply',
#   'sentiment': 'pos'},
#  {'name': '~\rAnnmarie',
#   'message': 'Does anyone have approx cost to instal borehole',
#   'sentiment': 'neutral'},
#  {'name': '~\rCraig Blend', 'message': 'Thanks Caron', 'sentiment': 'pos'},
#  {'name': 'Craig Blend',
#   'message': "I'm busy getting quotes atm but as I understand it depends on a couple of things. It costs around 2-5k just to see if there is borehole available then around 50k complete.",
#   'sentiment': 'neutral'},
#  {'name': 'Caron Hagues',
#   'message': 'It was there when we bought our house',
#   'sentiment': 'neutral'},
#  {'name': 'Annmarie', 'message': 'Ok thanks', 'sentiment': 'neutral'},
#  {'name': 'Piotr',
#   'message': 'I heard R1k per metre. One of my neighbours went down 80m. In the end to make it drinkable was around R200k',
#   'sentiment': 'neutral'},
#  {'name': 'Paul Congruence',
#   'message': "We went to 80m Nov 2016. Cost me 65k for hole & all the stuff on top incl. pump. We use for garden only, but shouldn't be too expensive to test, add necessary filters & pipe it into house. Currently 2 hours solid water flow & improving monthly. Ph or message me if you'd like to chat. Paul 0829295470",
#   'sentiment': 'neutral'},
#  {'name': 'Sherwin',
#   'message': 'Any one knows what the demand management levy of r20 is on our water acc for?',
#   'sentiment': 'neutral'},
#  {'name': 'Narra', 'message': "I'm driving right now", 'sentiment': 'neutral'},
#  {'name': 'Piotr', 'message': 'Just another tax 👍', 'sentiment': 'neutral'},
#  {'name': 'Giuseppe',
#   'message': 'Lovely, what did you get?👍',
#   'sentiment': 'pos'},
#  {'name': 'Giuseppe', 'message': 'Sorry wrong group', 'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Asking about who to report water issues to and providing information about a burst pipe.',
#   'sentiment': 'neutral'},
#  {'name': 'John Zeller',
#   'message': 'Asking if the burst pipe on Alma is causing the water pressure issue.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Confirming that the burst pipe is being repaired and water will be back in 3/4 hours.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': 'Inquiring about the Ernst Ullman Parkrun starting next weekend.',
#   'sentiment': 'neutral'},
#  {'name': 'Jon',
#   'message': 'Providing information that the Parkrun route is not on the website yet and sharing a link for more details.',
#   'sentiment': 'neutral'},
#  {'name': 'Matso at Rera Language School',
#   'message': 'Great initiative',
#   'sentiment': 'pos'},
#  {'name': 'Dr Mark Wertheimer',
#   'message': 'What date is the first one?',
#   'sentiment': 'neutral'},
#  {'name': 'Kim McCormick',
#   'message': '19 August, according to the Woodmead announcer on Saturday.',
#   'sentiment': 'neutral'},
#  {'name': 'Kim Silber',
#   'message': 'Thank you to the organisers! Fantastic to be able to walk to Parkrun.',
#   'sentiment': 'pos'},
#  {'name': 'Asha', 'message': '👏🏻👏🏻👏🏻awesome news', 'sentiment': 'pos'},
#  {'name': 'Craig', 'message': 'Another sad day for SA', 'sentiment': 'neg'},
#  {'name': 'P',
#   'message': '~P changed their phone number to a new number. Tap to message or add the new number.',
#   'sentiment': 'neutral'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Good morning, does anyone know of a AEG appliance repair company who is RELIABLE. Thanks',
#   'sentiment': 'neutral'},
#  {'name': 'Caren', 'message': 'Davenports. Very good.', 'sentiment': 'pos'},
#  {'name': 'Bernadette Phillips',
#   'message': 'Thanks Caren 😉',
#   'sentiment': 'pos'},
#  {'name': 'Justin',
#   'message': '7a is conducting free crime prevention training for domestic workers this Wednesday 12pm in the fields of Ullman Park. Even if your staff have been trained it is always good to have a refresher. A trained community is a safer community',
#   'sentiment': 'pos'},
#  {'name': 'Debby van Zyl',
#   'message': "Morning all. I'm looking for good reputable construction company to erect a boundary wall. Please whatsapp me directly if you know of anyone. Many thanks.",
#   'sentiment': 'neutral'},
#  {'name': 'Justin', 'message': 'Reminder', 'sentiment': 'neutral'},
#  {'name': 'Breena Bick',
#   'message': 'Thanks for adding me',
#   'sentiment': 'pos'},
#  {'name': 'Dave F',
#   'message': 'Hi all, I am looking for a carpenter. Can anyone assist with a contact.',
#   'sentiment': 'neutral'},
#  {'name': 'Richard',
#   'message': 'Also any suggestions for a paver and installation of gutters. Regards, Richard',
#   'sentiment': 'neutral'},
#  {'name': 'Michelle', 'message': 'Hi Dave an Richard', 'sentiment': 'neutral'},
#  {'name': 'Richard',
#   'message': 'Thanks Michelle, much appreciated',
#   'sentiment': 'pos'},
#  {'name': 'Louis',
#   'message': "My nanny's husband is a general contractor and has done some work for us in the past",
#   'sentiment': 'neutral'},
#  {'name': 'Dave F',
#   'message': 'Thanks guys - will contact them',
#   'sentiment': 'pos'},
#  ...]

# %%
#Calculate sentiment percentages

# To calculate the percentage of each sentiment category, we first need to count the number of messages
# in each category and then calculate the percentage based on the total number of messages.

# Counting the sentiments
sentiment_counts = {'pos': 0, 'neutral': 0, 'neg': 0}
for item in community_json_data:
    sentiment_counts[item['sentiment']] += 1

# Total number of messages
total_messages = len(community_json_data)

# Calculating the percentages
sentiment_percentages = {sentiment: (count / total_messages) * 100 for sentiment, count in sentiment_counts.items()}

sentiment_percentages
# Out:
# {'pos': 27.384324834749762,
#  'neutral': 52.40793201133145,
#  'neg': 20.20774315391879}

# %%
# who posted the most often?
# To calculate who posted the most often, we need to count the number of messages each person sent.

# Counting the number of messages each person sent
message_counts = {}
for item in community_json_data:
    if item['name'] in message_counts:
        message_counts[item['name']] += 1
    else:
        message_counts[item['name']] = 1

# Identifying the person who posted the most often
most_frequent_poster = max(message_counts, key=message_counts.get)
most_frequent_count = message_counts[most_frequent_poster]

most_frequent_poster, most_frequent_count
# Out:
# ('Scott', 60)

# %%
#who posted posted the most positive messages by number
# To calculate who posted positive messages the most often, we need to count the number of positive messages each person sent.

# Counting the number of positive messages each person sent
positive_message_counts = {}
for item in community_json_data:
    if item['sentiment'] == 'pos':
        if item['name'] in positive_message_counts:
            positive_message_counts[item['name']] += 1
        else:
            positive_message_counts[item['name']] = 1

# Identifying the person who posted the most positive messages
most_positive_poster = max(positive_message_counts, key=positive_message_counts.get, default=None)
most_positive_count = positive_message_counts.get(most_positive_poster, 0)

most_positive_poster, most_positive_count
# Out:
# ('Michelle & Giuseppe', 18)

# %%
#Who posted the most negative messages by number?
# To calculate who posted negative messages the most often, we need to count the number of negative messages each person sent.

# Counting the number of negative messages each person sent
negative_message_counts = {}
for item in community_json_data:
    if item['sentiment'] == 'neg':
        if item['name'] in negative_message_counts:
            negative_message_counts[item['name']] += 1
        else:
            negative_message_counts[item['name']] = 1

# Identifying the person who posted the most negative messages
most_negative_poster = max(negative_message_counts, key=negative_message_counts.get, default=None)
most_negative_count = negative_message_counts.get(most_negative_poster, 0)

most_negative_poster, most_negative_count
# Out:
# ('Michelle & Giuseppe', 17)

# %%
# Optional: Print page by page

def paginate(iterable, page_size):
    page = []
    for item in iterable:
        page.append(item)
        if len(page) == page_size:
            yield page
            page = []
    if page:
        yield page

# Example usage
for page in paginate(community_json_data, 10):  # Adjust page size as needed
    print(json.dumps(page, indent=4))
    input("Press Enter to continue to the next page...")  # Pause between pages

# %% [markdown]
# Now ask questions of the data

# %%
#create get_completion helper function
def get_completion(prompt,model="gpt-4-1106-preview"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature =0, #this is the degree of randomness 
    )
    return response.choices[0].message["content"]

# %%
# Ask the user to input a question
question = input("Please ask your question: ")
# Out:
# Please ask your question: who posted positive messages the nost often?

# %%
# Define a prompt
prompt = f"""
The JSON file delimited with triple backticks is taken from a Whatsapp channel for\
a neighbourhhood community group.\
Answer the question '''{question}''' by referring to the JSON file.\

Community responses: '''{community_json_data}'''
"""

# %%
# Get the completion
response = get_completion(prompt)
print(response)

# %%
# Optional: Define a function to print all the available info for a given name
def print_info_for_name(name_to_find, json_data):
    for record in community_json_data:
        if record['name'] == name_to_find:
            print(f"Information for {name_to_find}:")
            print("----------------------------------------")
            for key, value in record.items():
                print(f"{key}: {value}")

# %%
# Example usage
name_to_search = "James Drage"
print_info_for_name(name_to_search, json_data)
